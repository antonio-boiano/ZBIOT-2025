# %%
import pandas as pd
import os
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

base_dir = "D:/ZBIOT-2025/Dataset"
input_folder = os.path.join(base_dir, "Merged_Data", "A_6-Merged_sequence_data_fix_durations")
quantized_folder = os.path.join(base_dir, "Quantized_Data", "A_6-Merged_sequence_data_fix_durations", "Quantized_values")

file_name = "Topology_A_fix_duration_5s.csv"
original_file_path = os.path.join(input_folder, file_name)
new_file_name = file_name.replace(".csv", "")

b_values = list(range(1,32))
file_paths = {f"b{b}": os.path.join(quantized_folder, f"{new_file_name}_value_b{b}.csv") for b in b_values}
file_paths["Original"] = original_file_path

original_data = pd.read_csv(original_file_path)

X_original = original_data.drop(columns=["Device Name", "Device Type", "File Name"])
y_original = original_data["Device Type"]
y_original = y_original.astype("category")
categories = y_original.cat.categories
y_original = y_original.cat.codes

X_train, X_test, y_train, y_test_original = train_test_split(X_original, y_original, test_size=0.2, random_state=42, stratify=y_original)

class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

rf_model = RandomForestClassifier(random_state=42, class_weight=class_weight_dict)
rf_model.fit(X_train, y_train)

mean_accuracies = {}
std_accuracies = {}

from sklearn.metrics import ConfusionMatrixDisplay

for file_key, file_path in file_paths.items():
    if file_key == "Original":
        continue

    quantized_data = pd.read_csv(file_path)
    X_test_quantized = quantized_data.drop(columns=["Device Name", "Device Type", "File Name"]).iloc[y_test_original.index]
    y_test_quantized = quantized_data["Device Type"].iloc[y_test_original.index]
    y_test_quantized = y_test_quantized.astype("category")
    y_test_quantized = y_test_quantized.cat.set_categories(categories).cat.codes

    y_pred = rf_model.predict(X_test_quantized)
    F1_sc = f1_score(y_test_quantized, y_pred, average='weighted')
    mean_accuracies[file_key] = F1_sc
    std_accuracies[file_key] = 0

    print(f"\n=== Results for {file_key} ===")
    print(f"F1-Score = {F1_sc:.4f}")
    report = classification_report(y_test_quantized, y_pred, target_names=categories, zero_division=0)
    print(report)

    cm = confusion_matrix(y_test_quantized, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=categories)
    disp.plot(cmap='Blues', xticks_rotation=45)
    plt.title(f"Confusion Matrix for {file_key}")
    plt.tight_layout()
    plt.show()
# Out:
# === Results for b1 ===
# F1-Score = 0.2999
#               precision    recall  f1-score   support
#
#         Bulb       0.19      0.06      0.09       507
#  Coordinator       0.46      0.95      0.62      1135
#       Motion       0.00      0.00      0.00        36
#       Socket       0.00      0.00      0.00       817
#
#     accuracy                           0.44      2495
#    macro avg       0.16      0.25      0.18      2495
# weighted avg       0.25      0.44      0.30      2495
# === Results for b2 ===
# F1-Score = 0.4567
#               precision    recall  f1-score   support
#
#         Bulb       0.49      0.03      0.06       507
#  Coordinator       0.51      0.84      0.64      1135
#       Motion       0.00      0.00      0.00        36
#       Socket       0.56      0.40      0.47       817
#
#     accuracy                           0.52      2495
#    macro avg       0.39      0.32      0.29      2495
# weighted avg       0.52      0.52      0.46      2495
# === Results for b3 ===
# F1-Score = 0.6219
#               precision    recall  f1-score   support
#
#         Bulb       0.78      0.52      0.62       507
#  Coordinator       0.61      0.85      0.71      1135
#       Motion       1.00      0.33      0.50        36
#       Socket       0.62      0.42      0.50       817
#
#     accuracy                           0.64      2495
#    macro avg       0.75      0.53      0.58      2495
# weighted avg       0.65      0.64      0.62      2495
# === Results for b4 ===
# F1-Score = 0.8749
#               precision    recall  f1-score   support
#
#         Bulb       0.92      0.80      0.86       507
#  Coordinator       0.91      0.88      0.90      1135
#       Motion       1.00      0.36      0.53        36
#       Socket       0.82      0.93      0.87       817
#
#     accuracy                           0.88      2495
#    macro avg       0.91      0.75      0.79      2495
# weighted avg       0.88      0.88      0.87      2495
# === Results for b5 ===
# F1-Score = 0.8936
#               precision    recall  f1-score   support
#
#         Bulb       0.91      0.79      0.85       507
#  Coordinator       0.88      0.97      0.92      1135
#       Motion       0.93      0.36      0.52        36
#       Socket       0.92      0.88      0.90       817
#
#     accuracy                           0.90      2495
#    macro avg       0.91      0.75      0.80      2495
# weighted avg       0.90      0.90      0.89      2495
# === Results for b6 ===
# F1-Score = 0.9225
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.87      0.90       507
#  Coordinator       0.90      0.98      0.94      1135
#       Motion       0.93      0.36      0.52        36
#       Socket       0.95      0.91      0.93       817
#
#     accuracy                           0.92      2495
#    macro avg       0.93      0.78      0.82      2495
# weighted avg       0.93      0.92      0.92      2495
# === Results for b7 ===
# F1-Score = 0.9514
#               precision    recall  f1-score   support
#
#         Bulb       0.93      0.92      0.92       507
#  Coordinator       0.96      0.98      0.97      1135
#       Motion       0.76      0.61      0.68        36
#       Socket       0.96      0.95      0.95       817
#
#     accuracy                           0.95      2495
#    macro avg       0.90      0.86      0.88      2495
# weighted avg       0.95      0.95      0.95      2495
# === Results for b8 ===
# F1-Score = 0.9513
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.93      0.94       507
#  Coordinator       0.95      0.98      0.97      1135
#       Motion       0.93      0.39      0.55        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.95      2495
#    macro avg       0.95      0.81      0.85      2495
# weighted avg       0.95      0.95      0.95      2495
# === Results for b9 ===
# F1-Score = 0.9580
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.96      0.98      0.97      1135
#       Motion       0.95      0.58      0.72        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.96      0.86      0.90      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b10 ===
# F1-Score = 0.9603
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.96      0.98      0.97      1135
#       Motion       0.89      0.67      0.76        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.89      0.91      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b11 ===
# F1-Score = 0.9603
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.92      0.67      0.77        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.95      0.89      0.91      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b12 ===
# F1-Score = 0.9591
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.96      0.98      0.97      1135
#       Motion       0.89      0.67      0.76        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.89      0.91      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b13 ===
# F1-Score = 0.9603
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.89      0.67      0.76        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.89      0.91      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b14 ===
# F1-Score = 0.9605
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b15 ===
# F1-Score = 0.9609
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b16 ===
# F1-Score = 0.9609
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b17 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b18 ===
# F1-Score = 0.9605
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.94      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b19 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b20 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b21 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b22 ===
# F1-Score = 0.9609
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b23 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b24 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b25 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b26 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b27 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b28 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b29 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b30 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495
# === Results for b31 ===
# F1-Score = 0.9613
#               precision    recall  f1-score   support
#
#         Bulb       0.94      0.95      0.94       507
#  Coordinator       0.97      0.98      0.97      1135
#       Motion       0.90      0.72      0.80        36
#       Socket       0.97      0.95      0.96       817
#
#     accuracy                           0.96      2495
#    macro avg       0.94      0.90      0.92      2495
# weighted avg       0.96      0.96      0.96      2495

# %%
import pandas as pd
import os
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

def filter_small_classes(data, min_samples=15):
    class_counts = data["Device Name"].value_counts()
    classes_to_keep = class_counts[class_counts >= min_samples].index.tolist()
    filtered_data = data[data["Device Name"].isin(classes_to_keep)].copy()
    return filtered_data

base_dir = "D:/ZBIOT-2025/Dataset"
input_folder = os.path.join(base_dir, "Merged_Data", "A_6-Merged_sequence_data_fix_durations")
quantized_folder = os.path.join(base_dir, "Quantized_Data", "A_6-Merged_sequence_data_fix_durations", "Quantized_values")

file_name = "Topology_A_fix_duration_5s.csv"
original_file_path = os.path.join(input_folder, file_name)
new_file_name = file_name.replace(".csv", "")

b_values = list(range(1,32))
file_paths = {f"b{b}": os.path.join(quantized_folder, f"{new_file_name}_value_b{b}.csv") for b in b_values}
file_paths["Original"] = original_file_path

original_data = pd.read_csv(original_file_path)
original_data = filter_small_classes(original_data, 30)
X_original = original_data.drop(columns=["Device Name", "Device Type", "File Name"])
y_original = original_data["Device Name"]
y_original = y_original.astype("category")
categories = y_original.cat.categories
y_original = y_original.cat.codes

X_train, X_test, y_train, y_test_original = train_test_split(X_original, y_original, test_size=0.2, random_state=42, stratify=y_original)

class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

rf_model = RandomForestClassifier(random_state=42, class_weight=class_weight_dict)
rf_model.fit(X_train, y_train)

mean_accuracies = {}
std_accuracies = {}

from sklearn.metrics import ConfusionMatrixDisplay

for file_key, file_path in file_paths.items():
    if file_key == "Original":
        continue

    quantized_data = pd.read_csv(file_path)
    X_test_quantized = quantized_data.drop(columns=["Device Name", "Device Type", "File Name"]).iloc[y_test_original.index]
    y_test_quantized = quantized_data["Device Name"].iloc[y_test_original.index]
    y_test_quantized = y_test_quantized.astype("category")
    y_test_quantized = y_test_quantized.cat.set_categories(categories).cat.codes

    y_pred = rf_model.predict(X_test_quantized)
    F1_sc = f1_score(y_test_quantized, y_pred, average='weighted')
    mean_accuracies[file_key] = F1_sc
    std_accuracies[file_key] = 0

    print(f"\n=== Results for {file_key} ===")
    print(f"F1-Score = {F1_sc:.4f}")
    report = classification_report(y_test_quantized, y_pred, target_names=categories, zero_division=0)
    print(report)

    cm = confusion_matrix(y_test_quantized, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=categories)
    disp.plot(cmap='Blues', xticks_rotation=45)
    plt.title(f"Confusion Matrix for {file_key}")
    plt.tight_layout()
    plt.show()
# Out:
# === Results for b1 ===
# F1-Score = 0.2878
#                       precision    recall  f1-score   support
#
#          Coordinator       0.46      0.99      0.63      1135
#        Ledvance Bulb       0.05      0.02      0.03       153
# Ledvance Smart+ Plug       0.00      0.00      0.00        22
#     Ledvance Z3 Plug       0.00      0.00      0.00        27
#            Moes Bulb       0.00      0.00      0.00        94
#       Philips Lamp 1       0.00      0.00      0.00        90
#       Philips Lamp 2       0.00      0.00      0.00        70
#       Philips Lamp 3       0.00      0.00      0.00        36
#       Philips Motion       0.00      0.00      0.00       100
#         Power Plug 1       0.00      0.00      0.00       224
#         Power Plug 2       0.00      0.00      0.00       249
#         Smart Socket       0.00      0.00      0.00       295
#
#             accuracy                           0.45      2495
#            macro avg       0.04      0.08      0.05      2495
#         weighted avg       0.21      0.45      0.29      2495
# === Results for b2 ===
# F1-Score = 0.4223
#                       precision    recall  f1-score   support
#
#          Coordinator       0.54      0.87      0.66      1135
#        Ledvance Bulb       0.33      0.02      0.04       153
# Ledvance Smart+ Plug       0.00      0.00      0.00        22
#     Ledvance Z3 Plug       0.00      0.00      0.00        27
#            Moes Bulb       0.00      0.00      0.00        94
#       Philips Lamp 1       0.00      0.00      0.00        90
#       Philips Lamp 2       0.00      0.00      0.00        70
#       Philips Lamp 3       0.00      0.00      0.00        36
#       Philips Motion       0.17      0.01      0.02       100
#         Power Plug 1       0.26      0.28      0.27       224
#         Power Plug 2       0.41      0.48      0.44       249
#         Smart Socket       0.79      0.29      0.42       295
#
#             accuracy                           0.50      2495
#            macro avg       0.21      0.16      0.15      2495
#         weighted avg       0.43      0.50      0.42      2495
# === Results for b3 ===
# F1-Score = 0.6069
#                       precision    recall  f1-score   support
#
#          Coordinator       0.69      0.98      0.81      1135
#        Ledvance Bulb       0.82      0.69      0.75       153
# Ledvance Smart+ Plug       0.50      0.05      0.08        22
#     Ledvance Z3 Plug       1.00      0.04      0.07        27
#            Moes Bulb       0.87      0.29      0.43        94
#       Philips Lamp 1       0.46      0.19      0.27        90
#       Philips Lamp 2       0.15      0.03      0.05        70
#       Philips Lamp 3       0.91      0.28      0.43        36
#       Philips Motion       0.47      0.29      0.36       100
#         Power Plug 1       0.40      0.56      0.47       224
#         Power Plug 2       0.54      0.37      0.44       249
#         Smart Socket       0.93      0.34      0.49       295
#
#             accuracy                           0.65      2495
#            macro avg       0.64      0.34      0.39      2495
#         weighted avg       0.66      0.65      0.61      2495
# === Results for b4 ===
# F1-Score = 0.7123
#                       precision    recall  f1-score   support
#
#          Coordinator       0.77      0.99      0.87      1135
#        Ledvance Bulb       0.90      0.64      0.75       153
# Ledvance Smart+ Plug       0.80      0.18      0.30        22
#     Ledvance Z3 Plug       0.50      0.04      0.07        27
#            Moes Bulb       0.83      0.64      0.72        94
#       Philips Lamp 1       0.43      0.27      0.33        90
#       Philips Lamp 2       0.35      0.17      0.23        70
#       Philips Lamp 3       1.00      0.28      0.43        36
#       Philips Motion       0.64      0.37      0.47       100
#         Power Plug 1       0.55      0.59      0.57       224
#         Power Plug 2       0.60      0.58      0.59       249
#         Smart Socket       0.86      0.65      0.74       295
#
#             accuracy                           0.74      2495
#            macro avg       0.69      0.45      0.51      2495
#         weighted avg       0.73      0.74      0.71      2495
# === Results for b5 ===
# F1-Score = 0.7203
#                       precision    recall  f1-score   support
#
#          Coordinator       0.81      0.98      0.89      1135
#        Ledvance Bulb       0.83      0.79      0.81       153
# Ledvance Smart+ Plug       0.43      0.27      0.33        22
#     Ledvance Z3 Plug       1.00      0.07      0.14        27
#            Moes Bulb       0.89      0.53      0.67        94
#       Philips Lamp 1       0.49      0.38      0.42        90
#       Philips Lamp 2       0.50      0.47      0.49        70
#       Philips Lamp 3       1.00      0.36      0.53        36
#       Philips Motion       0.61      0.42      0.50       100
#         Power Plug 1       0.48      0.73      0.58       224
#         Power Plug 2       0.62      0.54      0.58       249
#         Smart Socket       0.96      0.43      0.59       295
#
#             accuracy                           0.74      2495
#            macro avg       0.72      0.50      0.54      2495
#         weighted avg       0.76      0.74      0.72      2495
# === Results for b6 ===
# F1-Score = 0.7789
#                       precision    recall  f1-score   support
#
#          Coordinator       0.87      0.99      0.92      1135
#        Ledvance Bulb       0.87      0.88      0.87       153
# Ledvance Smart+ Plug       0.45      0.41      0.43        22
#     Ledvance Z3 Plug       0.77      0.37      0.50        27
#            Moes Bulb       0.94      0.70      0.80        94
#       Philips Lamp 1       0.44      0.36      0.40        90
#       Philips Lamp 2       0.48      0.41      0.44        70
#       Philips Lamp 3       0.93      0.36      0.52        36
#       Philips Motion       0.58      0.60      0.59       100
#         Power Plug 1       0.73      0.53      0.61       224
#         Power Plug 2       0.57      0.73      0.64       249
#         Smart Socket       0.89      0.64      0.75       295
#
#             accuracy                           0.79      2495
#            macro avg       0.71      0.58      0.62      2495
#         weighted avg       0.79      0.79      0.78      2495
# === Results for b7 ===
# F1-Score = 0.8198
#                       precision    recall  f1-score   support
#
#          Coordinator       0.92      0.99      0.95      1135
#        Ledvance Bulb       0.86      0.90      0.88       153
# Ledvance Smart+ Plug       0.42      0.36      0.39        22
#     Ledvance Z3 Plug       0.88      0.26      0.40        27
#            Moes Bulb       0.92      0.82      0.87        94
#       Philips Lamp 1       0.51      0.37      0.43        90
#       Philips Lamp 2       0.55      0.63      0.59        70
#       Philips Lamp 3       0.74      0.72      0.73        36
#       Philips Motion       0.61      0.60      0.61       100
#         Power Plug 1       0.71      0.65      0.68       224
#         Power Plug 2       0.66      0.77      0.71       249
#         Smart Socket       0.91      0.72      0.80       295
#
#             accuracy                           0.83      2495
#            macro avg       0.72      0.65      0.67      2495
#         weighted avg       0.82      0.83      0.82      2495
# === Results for b8 ===
# F1-Score = 0.8223
#                       precision    recall  f1-score   support
#
#          Coordinator       0.91      0.99      0.95      1135
#        Ledvance Bulb       0.85      0.90      0.88       153
# Ledvance Smart+ Plug       0.60      0.41      0.49        22
#     Ledvance Z3 Plug       0.90      0.33      0.49        27
#            Moes Bulb       0.93      0.83      0.88        94
#       Philips Lamp 1       0.43      0.29      0.35        90
#       Philips Lamp 2       0.48      0.60      0.53        70
#       Philips Lamp 3       0.83      0.42      0.56        36
#       Philips Motion       0.63      0.58      0.60       100
#         Power Plug 1       0.77      0.64      0.70       224
#         Power Plug 2       0.69      0.77      0.73       249
#         Smart Socket       0.86      0.82      0.84       295
#
#             accuracy                           0.83      2495
#            macro avg       0.74      0.63      0.67      2495
#         weighted avg       0.82      0.83      0.82      2495
# === Results for b9 ===
# F1-Score = 0.8436
#                       precision    recall  f1-score   support
#
#          Coordinator       0.93      0.99      0.96      1135
#        Ledvance Bulb       0.84      0.90      0.87       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.75      0.33      0.46        27
#            Moes Bulb       0.97      0.82      0.89        94
#       Philips Lamp 1       0.44      0.38      0.41        90
#       Philips Lamp 2       0.54      0.63      0.58        70
#       Philips Lamp 3       0.84      0.75      0.79        36
#       Philips Motion       0.66      0.60      0.63       100
#         Power Plug 1       0.71      0.74      0.73       224
#         Power Plug 2       0.75      0.78      0.77       249
#         Smart Socket       0.92      0.81      0.86       295
#
#             accuracy                           0.85      2495
#            macro avg       0.76      0.68      0.71      2495
#         weighted avg       0.85      0.85      0.84      2495
# === Results for b10 ===
# F1-Score = 0.8458
#                       precision    recall  f1-score   support
#
#          Coordinator       0.93      0.99      0.96      1135
#        Ledvance Bulb       0.83      0.89      0.86       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.64      0.33      0.44        27
#            Moes Bulb       0.96      0.82      0.89        94
#       Philips Lamp 1       0.42      0.46      0.44        90
#       Philips Lamp 2       0.60      0.51      0.55        70
#       Philips Lamp 3       0.92      0.67      0.77        36
#       Philips Motion       0.62      0.56      0.59       100
#         Power Plug 1       0.76      0.70      0.73       224
#         Power Plug 2       0.77      0.81      0.79       249
#         Smart Socket       0.89      0.85      0.87       295
#
#             accuracy                           0.85      2495
#            macro avg       0.76      0.67      0.70      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b11 ===
# F1-Score = 0.8511
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.83      0.91      0.87       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.83      0.89        94
#       Philips Lamp 1       0.51      0.37      0.43        90
#       Philips Lamp 2       0.55      0.57      0.56        70
#       Philips Lamp 3       0.79      0.72      0.75        36
#       Philips Motion       0.64      0.67      0.65       100
#         Power Plug 1       0.76      0.71      0.74       224
#         Power Plug 2       0.76      0.79      0.77       249
#         Smart Socket       0.91      0.88      0.89       295
#
#             accuracy                           0.86      2495
#            macro avg       0.78      0.68      0.71      2495
#         weighted avg       0.85      0.86      0.85      2495
# === Results for b12 ===
# F1-Score = 0.8513
#                       precision    recall  f1-score   support
#
#          Coordinator       0.93      0.99      0.96      1135
#        Ledvance Bulb       0.83      0.90      0.87       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.77      0.37      0.50        27
#            Moes Bulb       0.97      0.83      0.90        94
#       Philips Lamp 1       0.50      0.47      0.48        90
#       Philips Lamp 2       0.55      0.59      0.57        70
#       Philips Lamp 3       0.93      0.69      0.79        36
#       Philips Motion       0.68      0.59      0.63       100
#         Power Plug 1       0.77      0.71      0.73       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.87      0.88       295
#
#             accuracy                           0.86      2495
#            macro avg       0.78      0.68      0.72      2495
#         weighted avg       0.85      0.86      0.85      2495
# === Results for b13 ===
# F1-Score = 0.8521
#                       precision    recall  f1-score   support
#
#          Coordinator       0.93      0.99      0.96      1135
#        Ledvance Bulb       0.84      0.91      0.87       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.82      0.33      0.47        27
#            Moes Bulb       0.96      0.83      0.89        94
#       Philips Lamp 1       0.51      0.48      0.49        90
#       Philips Lamp 2       0.58      0.53      0.55        70
#       Philips Lamp 3       0.89      0.69      0.78        36
#       Philips Motion       0.66      0.65      0.65       100
#         Power Plug 1       0.76      0.71      0.73       224
#         Power Plug 2       0.76      0.79      0.77       249
#         Smart Socket       0.90      0.87      0.89       295
#
#             accuracy                           0.86      2495
#            macro avg       0.78      0.68      0.72      2495
#         weighted avg       0.85      0.86      0.85      2495
# === Results for b14 ===
# F1-Score = 0.8507
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.84      0.92      0.88       153
# Ledvance Smart+ Plug       0.73      0.36      0.48        22
#     Ledvance Z3 Plug       0.82      0.33      0.47        27
#            Moes Bulb       0.95      0.83      0.89        94
#       Philips Lamp 1       0.49      0.43      0.46        90
#       Philips Lamp 2       0.57      0.57      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.67      0.63      0.65       100
#         Power Plug 1       0.75      0.70      0.72       224
#         Power Plug 2       0.76      0.80      0.77       249
#         Smart Socket       0.90      0.86      0.88       295
#
#             accuracy                           0.86      2495
#            macro avg       0.77      0.68      0.71      2495
#         weighted avg       0.85      0.86      0.85      2495
# === Results for b15 ===
# F1-Score = 0.8516
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.84      0.91      0.87       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.95      0.84      0.89        94
#       Philips Lamp 1       0.48      0.41      0.44        90
#       Philips Lamp 2       0.55      0.60      0.58        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.66      0.61      0.64       100
#         Power Plug 1       0.75      0.71      0.72       224
#         Power Plug 2       0.77      0.80      0.78       249
#         Smart Socket       0.90      0.86      0.88       295
#
#             accuracy                           0.86      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.86      0.85      2495
# === Results for b16 ===
# F1-Score = 0.8499
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.90      0.33      0.49        27
#            Moes Bulb       0.95      0.83      0.89        94
#       Philips Lamp 1       0.47      0.43      0.45        90
#       Philips Lamp 2       0.56      0.56      0.56        70
#       Philips Lamp 3       0.87      0.75      0.81        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.69      0.72       224
#         Power Plug 2       0.75      0.80      0.78       249
#         Smart Socket       0.90      0.86      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.68      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b17 ===
# F1-Score = 0.8530
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.98      0.84      0.90        94
#       Philips Lamp 1       0.48      0.44      0.46        90
#       Philips Lamp 2       0.57      0.56      0.56        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.75      0.70      0.72       224
#         Power Plug 2       0.76      0.80      0.78       249
#         Smart Socket       0.90      0.87      0.88       295
#
#             accuracy                           0.86      2495
#            macro avg       0.79      0.69      0.72      2495
#         weighted avg       0.85      0.86      0.85      2495
# === Results for b18 ===
# F1-Score = 0.8512
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.46      0.43      0.45        90
#       Philips Lamp 2       0.57      0.56      0.56        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.75      0.71      0.72       224
#         Power Plug 2       0.75      0.80      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b19 ===
# F1-Score = 0.8496
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.98      0.84      0.90        94
#       Philips Lamp 1       0.46      0.43      0.45        90
#       Philips Lamp 2       0.56      0.56      0.56        70
#       Philips Lamp 3       0.87      0.75      0.81        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.70      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.87       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b20 ===
# F1-Score = 0.8507
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.46      0.43      0.45        90
#       Philips Lamp 2       0.57      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b21 ===
# F1-Score = 0.8505
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.98      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.57      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.67      0.62      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b22 ===
# F1-Score = 0.8504
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.67      0.62      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b23 ===
# F1-Score = 0.8504
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.67      0.62      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b24 ===
# F1-Score = 0.8504
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.67      0.62      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b25 ===
# F1-Score = 0.8504
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.67      0.62      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b26 ===
# F1-Score = 0.8509
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b27 ===
# F1-Score = 0.8509
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b28 ===
# F1-Score = 0.8509
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b29 ===
# F1-Score = 0.8509
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b30 ===
# F1-Score = 0.8509
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
# === Results for b31 ===
# F1-Score = 0.8509
#                       precision    recall  f1-score   support
#
#          Coordinator       0.94      0.99      0.96      1135
#        Ledvance Bulb       0.85      0.91      0.88       153
# Ledvance Smart+ Plug       0.75      0.41      0.53        22
#     Ledvance Z3 Plug       0.91      0.37      0.53        27
#            Moes Bulb       0.96      0.84      0.90        94
#       Philips Lamp 1       0.45      0.43      0.44        90
#       Philips Lamp 2       0.58      0.56      0.57        70
#       Philips Lamp 3       0.88      0.78      0.82        36
#       Philips Motion       0.68      0.63      0.65       100
#         Power Plug 1       0.74      0.71      0.72       224
#         Power Plug 2       0.75      0.79      0.77       249
#         Smart Socket       0.90      0.85      0.88       295
#
#             accuracy                           0.85      2495
#            macro avg       0.78      0.69      0.72      2495
#         weighted avg       0.85      0.85      0.85      2495
